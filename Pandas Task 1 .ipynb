# %%
                                                         #Practice Questions
                                                         #1-Basic Exploration
import pandas as pd
data=pd.read_csv("E:\\Datasets\\products-10000.csv")
data
# Out:
#       Index                                        Name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 3         4              Premium Grill Trimmer Portable
# 4         5                            Keyboard Freezer
# ...     ...                                         ...
# 9995   9996                                   Powerbank
# 9996   9997            Rechargeable Lamp Scanner Vacuum
# 9997   9998                                      Heater
# 9998   9999               Rechargeable Headphones Stove
# 9999  10000                     Clean Charger Treadmill
#
#                                             Description  \
# 0                             Catch enough role nearly.
# 1                             All movement yeah tax me.
# 2                   Quickly inside pull line lay start.
# 3                                 Lawyer one than fire.
# ...

# %%
#1.	What is the shape of the dataset?
print("Shape of data set is :",data.shape)
# Out:
# Shape of data set is : (10000, 13)

# %%
#2.	What are the column names and their data types?
print("Column names are :",data.columns)
# Out:
# Column names are : Index(['Index', 'Name', 'Description', 'Brand', 'Category', 'Price',
#        'Currency', 'Stock', 'EAN', 'Color', 'Size', 'Availability',
#        'Internal ID'],
#       dtype='object')

# %%
print("Datatyes of Columns are:")
data.dtypes
# Out:
# Datatyes of Columns are:
# Index            int64
# Name            object
# Description     object
# Brand           object
# Category        object
# Price            int64
# Currency        object
# Stock            int64
# EAN              int64
# Color           object
# Size            object
# Availability    object
# Internal ID      int64
# dtype: object

# %%
#3.	Show the first 5 and last 5 rows.
print("First 5 Rows are :")
data.head()
# Out:
# First 5 Rows are :
#    Index                                        Name  \
# 0      1  Smart Fan Iron Cooker Go Wireless Portable
# 1      2                                         Fan
# 2      3   Smart Speakerphone Charger Eco Plus Clean
# 3      4              Premium Grill Trimmer Portable
# 4      5                            Keyboard Freezer
#
#                            Description                    Brand  \
# 0            Catch enough role nearly.               Herman Ltd
# 1            All movement yeah tax me.  Braun, King and Rollins
# 2  Quickly inside pull line lay start.             Peck-Coleman
# 3                Lawyer one than fire.                Hines Ltd
# 4    Remain Congress blood plan voice.  Spence, Webster and Orr
#
#               Category  Price Currency  Stock            EAN        Color  \
# 0       Kids' Clothing    585      USD    194  3968600833473     Cornsilk
# 1       Grooming Tools    992      USD    724   191126950284       Bisque
# ...

# %%
print("Last 5 Rows are :")
data.tail()
# Out:
# Last 5 Rows are :
#       Index                              Name  \
# 9995   9996                         Powerbank
# 9996   9997  Rechargeable Lamp Scanner Vacuum
# 9997   9998                            Heater
# 9998   9999     Rechargeable Headphones Stove
# 9999  10000           Clean Charger Treadmill
#
#                                             Description  \
# 9995                  Yeah none boy fund city decision.
# 9996    Appear country enter there pull thing computer.
# 9997  Owner plan approach soldier church little little.
# 9998                     Base account partner probably.
# 9999        Return reflect truth tell scientist season.
#
#                       Brand            Category  Price Currency  Stock  \
# 9995     Castaneda-Harrison  Books & Stationery    567      USD     27
# 9996              Knapp-Key             Cycling    300      USD    177
# 9997  Meyer, Case and Mills   Fitness Equipment    399      USD    996
# ...

# %%
#4.	How many missing values are there in each column? What % of the column is missing?
print("Missing values in each column are :")
data.isnull().sum()
# Out:
# Missing values in each column are :
# Index           0
# Name            0
# Description     0
# Brand           0
# Category        0
# Price           0
# Currency        0
# Stock           0
# EAN             0
# Color           0
# Size            0
# Availability    0
# Internal ID     0
# dtype: int64

# %%
#What % of the column is missing?
print("Percentage of missing values are :")
(data.isnull().mean()*100).round(2)
# Out:
# Percentage of missing values are :
# Index           0.0
# Name            0.0
# Description     0.0
# Brand           0.0
# Category        0.0
# Price           0.0
# Currency        0.0
# Stock           0.0
# EAN             0.0
# Color           0.0
# Size            0.0
# Availability    0.0
# Internal ID     0.0
# dtype: float64

# %%
#5.	Are there any duplicate rows?
print("Duplicate Rows are:",data.duplicated().sum())
#data.duplicated().sum()
# Out:
# Duplicate Rows are: 0

# %%
                                                      #2. Column & Row Selection
file_path=("E:\\Datasets\\products-10000.csv")
#1.	Select only the Name, Brand, Price, and Stock columns.
data=pd.read_csv(file_path,usecols=[1,3,5,7])
data
#data = pd.read_csv(file_path, usecols=["Name", "Brand", "Price", "Stock"])
# Out:
#                                             Name                    Brand  \
# 0     Smart Fan Iron Cooker Go Wireless Portable               Herman Ltd
# 1                                            Fan  Braun, King and Rollins
# 2      Smart Speakerphone Charger Eco Plus Clean             Peck-Coleman
# 3                 Premium Grill Trimmer Portable                Hines Ltd
# 4                               Keyboard Freezer  Spence, Webster and Orr
# ...                                          ...                      ...
# 9995                                   Powerbank       Castaneda-Harrison
# 9996            Rechargeable Lamp Scanner Vacuum                Knapp-Key
# 9997                                      Heater    Meyer, Case and Mills
# 9998               Rechargeable Headphones Stove               Jones-Bell
# 9999                     Clean Charger Treadmill                Davis LLC
#
#       Price  Stock
# 0       585    194
# 1       992    724
# ...

# %%
#2.	Get row number 10 using .iloc and .loc.
data.iloc[10]
# Out:
# Index                                         11
# Name                       Thermostat Stove Lamp
# Description     Pull perhaps customer available.
# Brand                              Moreno-Weaver
# Category                          Kids' Clothing
# Price                                        707
# Currency                                     USD
# Stock                                        257
# EAN                                6886778382210
# Color                                    Thistle
# Size                                           M
# Availability                        discontinued
# Internal ID                                   33
# Name: 10, dtype: object

# %%
data.loc[10]
# Out:
# Index                                         11
# Name                       Thermostat Stove Lamp
# Description     Pull perhaps customer available.
# Brand                              Moreno-Weaver
# Category                          Kids' Clothing
# Price                                        707
# Currency                                     USD
# Stock                                        257
# EAN                                6886778382210
# Color                                    Thistle
# Size                                           M
# Availability                        discontinued
# Internal ID                                   33
# Name: 10, dtype: object

# %%
#3.	Select the first 10 rows and only the Category and Price columns.
data=pd.read_csv(file_path,nrows=10,usecols=[4,5])
data
# Out:
#                  Category  Price
# 0          Kids' Clothing    585
# 1          Grooming Tools    992
# 2       Fishing & Hunting    940
# 3                Skincare    324
# 4     Laptops & Computers    908
# 5      Kitchen Appliances    627
# 6       Fishing & Hunting    385
# 7                Skincare    296
# 8      Clothing & Apparel    870
# 9  Beauty & Personal Care    602

# %%
#4.	Show the product Name and Price for all items where Category == "Kitchen Appliances".
data = pd.read_csv(file_path)
d = data.loc[data["Category"] == "Kitchen Appliances", ["Name", "Price"]]
d
# Out:
#                                                    Name  Price
# 5                                     Smart Fridge Plus    627
# 55    Advanced Thermostat Microphone Scooter Clean S...    425
# 64                        Ultra Drone Wireless Go Clean    119
# 187                        Wireless Webcam Mouse Silent    725
# 206                                       Scanner Mouse    143
# ...                                                 ...    ...
# 9897                                   Eco Speakerphone    451
# 9916                                  Eco Treadmill Pro    165
# 9921                                 Fast Blender Scale    494
# 9942                      Portable Bicycle Lock Fan One    197
# 9998                      Rechargeable Headphones Stove     45
#
# [319 rows x 2 columns]

# %%
#Method 2
#result = pd.read_csv(file_path).loc[lambda df: df["Category"] == "Kitchen Appliances", ["Name", "Price"]]
#result
# Out:
#                                                    Name  Price
# 5                                     Smart Fridge Plus    627
# 55    Advanced Thermostat Microphone Scooter Clean S...    425
# 64                        Ultra Drone Wireless Go Clean    119
# 187                        Wireless Webcam Mouse Silent    725
# 206                                       Scanner Mouse    143
# ...                                                 ...    ...
# 9897                                   Eco Speakerphone    451
# 9916                                  Eco Treadmill Pro    165
# 9921                                 Fast Blender Scale    494
# 9942                      Portable Bicycle Lock Fan One    197
# 9998                      Rechargeable Headphones Stove     45
#
# [319 rows x 2 columns]

# %%
                                                  #3. Filtering with Conditions
#1.	Find all products with Price > 500.
data[data["Price"] > 500]
# Out:
#       Index                                        Name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 4         5                            Keyboard Freezer
# 5         6                           Smart Fridge Plus
# ...     ...                                         ...
# 9991   9992                                  Silent Fan
# 9992   9993           Smart Trimmer Stove Advanced Plus
# 9993   9994                                 Scale Clock
# 9994   9995                                     Blender
# 9995   9996                                   Powerbank
#
#                                           Description  \
# 0                           Catch enough role nearly.
# 1                           All movement yeah tax me.
# 2                 Quickly inside pull line lay start.
# 4                   Remain Congress blood plan voice.
# ...

# %%
#2.	Find all products with Stock == 0.
data[data["Stock"] == 0]
# no zero stock exist
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Brand, Category, Price, Currency, Stock, EAN, Color, Size, Availability, Internal ID]
# Index: []

# %%
#3.	Show all products from the brand "Mueller Inc".
data[data["Brand"] == "Mueller Inc"]
# this brand is not existed
# Out:
# Empty DataFrame
# Columns: [Index, Name, Description, Brand, Category, Price, Currency, Stock, EAN, Color, Size, Availability, Internal ID]
# Index: []

# %%
brand_name = "Mueller Inc"
result = data[data["Brand"] == brand_name]
if result.empty:
    print(f"The brand '{brand_name}' does not exist in the dataset.")
else:
    print(result)
# Out:
# The brand 'Mueller Inc' does not exist in the dataset.

# %%
#4.	Show products where Price > 300 and Stock < 100.
data[(data["Price"] >300) & (data["Stock"] <100 )]
# Out:
#       Index                                 Name  \
# 3         4       Premium Grill Trimmer Portable
# 17       18                              Blender
# 18       19  Wireless Speakerphone Oven Advanced
# 27       28                            Ultra Fan
# 31       32     Mini Mixer Freezer Trimmer Smart
# ...     ...                                  ...
# 9975   9976                    Microphone Camera
# 9987   9988                Wireless Radio Silent
# 9988   9989                    Eco Mouse Compact
# 9993   9994                          Scale Clock
# 9995   9996                            Powerbank
#
#                                             Description  \
# 3                                 Lawyer one than fire.
# 17                        Bit dog upon sometimes trade.
# 18    Something the interview actually book white easy.
# 27    Structure training receive name collection stu...
# 31    Impact prepare religious public everyone allow...
# ...

# %%
#5.	Show products where Category == "Shoes & Footwear" or Category == "Books & Stationery".
# Method 1
data[(data["Category"]=="Shoes & Footwear" )| (data["Category"]=="Books & Stationery")]
# Out:
#       Index                              Name  \
# 48       49                   Ultra Watch Eco
# 49       50          Fast Lamp Scanner Vacuum
# 126     127                        Stove Iron
# 139     140       Rechargeable Treadmill Dock
# 162     163  Smart Fan Powerbank 360 Advanced
# ...     ...                               ...
# 9863   9864    Automatic Fridge Mouse Monitor
# 9872   9873              Digital Toaster Plus
# 9947   9948         Automatic Grill Phone Eco
# 9952   9953          Ultra Freezer Phone Edge
# 9995   9996                         Powerbank
#
#                                             Description  \
# 48     Eye analysis require create community knowledge.
# 49    There respond common travel as language everyt...
# 126                She system office theory happy more.
# 139        Nothing behind suggest whole college answer.
# 162                             Allow plant within how.
# ...                                                 ...
# ...

# %%
# Method 2
data[data["Category"].isin(["Shoes & Footwear" ,"Books & Stationery"])]
# Out:
#       Index                              Name  \
# 48       49                   Ultra Watch Eco
# 49       50          Fast Lamp Scanner Vacuum
# 126     127                        Stove Iron
# 139     140       Rechargeable Treadmill Dock
# 162     163  Smart Fan Powerbank 360 Advanced
# ...     ...                               ...
# 9863   9864    Automatic Fridge Mouse Monitor
# 9872   9873              Digital Toaster Plus
# 9947   9948         Automatic Grill Phone Eco
# 9952   9953          Ultra Freezer Phone Edge
# 9995   9996                         Powerbank
#
#                                             Description  \
# 48     Eye analysis require create community knowledge.
# 49    There respond common travel as language everyt...
# 126                She system office theory happy more.
# 139        Nothing behind suggest whole college answer.
# 162                             Allow plant within how.
# ...                                                 ...
# ...

# %%
#6.	Show products with Availability == "pre_order".
data[data["Availability"] == "pre_order"]
# Out:
#       Index                                       Name  \
# 2         3  Smart Speakerphone Charger Eco Plus Clean
# 5         6                          Smart Fridge Plus
# 11       12                   Mini Powerbank Lite Plus
# 15       16            Ultra Powerbank Scale Automatic
# 23       24           Smart Microphone Clock Ultra One
# ...     ...                                        ...
# 9987   9988                      Wireless Radio Silent
# 9991   9992                                 Silent Fan
# 9992   9993          Smart Trimmer Stove Advanced Plus
# 9995   9996                                  Powerbank
# 9997   9998                                     Heater
#
#                                             Description  \
# 2                   Quickly inside pull line lay start.
# 5                   Tell tend provide government voice.
# 11                                      Still can tell.
# 15              Against or catch tough nor wait reason.
# ...

# %%
#7.	Show products whose Name starts with "Smart".
data[data["Name"].str.startswith("Smart")]
# Out:
#       Index                                        Name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 5         6                           Smart Fridge Plus
# 23       24            Smart Microphone Clock Ultra One
# 29       30                         Smart Lock Mini Pro
# ...     ...                                         ...
# 9971   9972             Smart Router Keyboard One Ultra
# 9978   9979                                 Smart Drone
# 9985   9986         Smart Phone Automatic Advanced Plus
# 9989   9990                          Smart Speakerphone
# 9992   9993           Smart Trimmer Stove Advanced Plus
#
#                                             Description  \
# 0                             Catch enough role nearly.
# 2                   Quickly inside pull line lay start.
# 5                   Tell tend provide government voice.
# 23                               Open section note all.
# ...

# %%
                                                               #4. Sorting
#1.	Sort products by Price ascending.
data.sort_values(by="Price")
# Out:
#       Index                                       Name  \
# 5121   5122                    Smart Radio Pro Ultra X
# 6027   6028               Advanced Powerbank Projector
# 4613   4614                     Advanced Treadmill 360
# 1374   1375        Mini Mixer Router Phone Smart Prime
# 7496   7497  Premium Microphone Headphones Touch Sense
# ...     ...                                        ...
# 6573   6574              Mini Oven Drone Mini Portable
# 8348   8349               Premium Toaster Scooter Edge
# 3931   3932                             Ultra Keyboard
# 3576   3577            Pro Clock Router Fridge Air Max
# 2717   2718                                 Mini Brush
#
#                                             Description  \
# 5121                       To skill senior than career.
# 6027     Long significant on score kind cultural agree.
# 4613                          Miss by employee medical.
# 1374                Adult open alone position cultural.
# ...

# %%
#2.	Sort products by Stock descending.
data.sort_values(by="Stock",ascending=False)
# Out:
#       Index                                 Name  \
# 2348   2349         Bicycle Speakerphone Printer
# 7210   7211                         Dock Trimmer
# 7168   7169    Rechargeable Scale Stove Pro Plus
# 456     457                         Iron Monitor
# 8516   8517                Trimmer Webcam Heater
# ...     ...                                  ...
# 8106   8107            Mini Brush Blender Vacuum
# 5636   5637       Silent Cooker Cooler Touch 360
# 3164   3165            Ultra Radio Smart Max 360
# 558     559             Advanced Router Portable
# 497     498  Smart Charger Mini Max Rechargeable
#
#                                             Description  \
# 2348              Decision billion special raise seven.
# 7210              Challenge fire enjoy understand tree.
# 7168                           Role fall billion three.
# 456                              Three will total born.
# 8516  Image technology economy floor quite popular d...
# ...

# %%
#3.	Sort by Category and within each category by Price (highest first).
data.sort_values(by=["category", "price"], ascending=[True, False])
# true for alphabetical order andd false for descending order
# Out:
#       index                                               name  \
# 6745   6746                                          Ultra Fan
# 2017   2018                                         Ultra Dock
# 1133   1134        Rechargeable Tablet Microphone Trimmer Plus
# 2577   2578   Fast Vacuum Iron Phone Wireless Premium Wireless
# 9418   9419                                          Treadmill
# ...     ...                                                ...
# 1859   1860                                 Advanced Powerbank
# 331     332                                            Scooter
# 4187   4188                                      Portable Dock
# 4069   4070                                          Fast Lock
# 2505   2506  Smart Charger Stove Watch Digital Mini Recharg...
#
#                                             description  \
# 6745         Recently up sure why project deal feeling.
# 2017  Begin call garden interesting through everyone...
# ...

# %%
                                                        #5. Renaming & Removing
#1.	Rename columns Internal ID/→ internal_id, EAN → product_code, Price → unit_price.
d=data.rename(columns={
"Internal ID":"internal_id",
    "EAN":"product_code",
    "Price":"unit_price"})
print("After changing Names")
d.head()
# Out:
# After changing Names
#    index                                        name  \
# 0      1  Smart Fan Iron Cooker Go Wireless Portable
# 1      2                                         Fan
# 2      3   Smart Speakerphone Charger Eco Plus Clean
# 3      4              Premium Grill Trimmer Portable
# 4      5                            Keyboard Freezer
#
#                            description                    brand  \
# 0            Catch enough role nearly.               Herman Ltd
# 1            All movement yeah tax me.  Braun, King and Rollins
# 2  Quickly inside pull line lay start.             Peck-Coleman
# 3                Lawyer one than fire.                Hines Ltd
# 4    Remain Congress blood plan voice.  Spence, Webster and Orr
#
#               category  price currency  stock            ean        color  \
# 0       Kids' Clothing    585      USD    194  3968600833473     Cornsilk
# 1       Grooming Tools    992      USD    724   191126950284       Bisque
# ...

# %%
#2.	Make all column names lowercase with underscores.
data.columns = data.columns.str.strip().str.lower().str.replace(" ", "_")


print(data.columns)
# Out:
# Index(['index', 'name', 'description', 'brand', 'category', 'price',
#        'currency', 'stock', 'ean', 'color', 'size', 'availability',
#        'internal_id'],
#       dtype='object')

# %%
#3.	Remove the Description column.
data.drop("description",axis=1)
# Out:
#       index                                        name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 3         4              Premium Grill Trimmer Portable
# 4         5                            Keyboard Freezer
# ...     ...                                         ...
# 9995   9996                                   Powerbank
# 9996   9997            Rechargeable Lamp Scanner Vacuum
# 9997   9998                                      Heater
# 9998   9999               Rechargeable Headphones Stove
# 9999  10000                     Clean Charger Treadmill
#
#                         brand             category  price currency  stock  \
# 0                  Herman Ltd       Kids' Clothing    585      USD    194
# 1     Braun, King and Rollins       Grooming Tools    992      USD    724
# ...

# %%
#4.	Remove both EAN and Internal ID (since they’re identifiers).
data.drop(["ean","internal_id"],axis=1)
# Out:
#       index                                        name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 3         4              Premium Grill Trimmer Portable
# 4         5                            Keyboard Freezer
# ...     ...                                         ...
# 9995   9996                                   Powerbank
# 9996   9997            Rechargeable Lamp Scanner Vacuum
# 9997   9998                                      Heater
# 9998   9999               Rechargeable Headphones Stove
# 9999  10000                     Clean Charger Treadmill
#
#                                             description  \
# 0                             Catch enough role nearly.
# 1                             All movement yeah tax me.
# 2                   Quickly inside pull line lay start.
# 3                                 Lawyer one than fire.
# ...

# %%
                                                         #6. Descriptive Statistics
#1.	What is the average price of products?
print("Average price of products is :",data["price"].mean())
# Out:
# Average price of products is : 503.3702

# %%
#2.	What is the maximum and minimum price? Which products are these?
data["price"].agg(["min", "max"])
# Out:
# min      1
# max    999
# Name: price, dtype: int64

# %%
min_price = data["price"].min()
max_price = data["price"].max()

# minimum price
print("Products with Minimum Price:")
print(data[data["price"] == min_price][["name", "price"]])

# maximum price
print("\nProducts with Maximum Price:")
print(data[data["price"] == max_price][["name", "price"]])
# Out:
# Products with Minimum Price:
#                                            name  price
# 1032                     Pro Drone Vacuum Clean      1
# 1374        Mini Mixer Router Phone Smart Prime      1
# 2569                               Silent Brush      1
# 2865     Premium Clock Brush Advanced Touch Eco      1
# 4613                     Advanced Treadmill 360      1
# 5121                    Smart Radio Pro Ultra X      1
# 6027               Advanced Powerbank Projector      1
# 6543             Portable Microphone Headphones      1
# 7496  Premium Microphone Headphones Touch Sense      1
# 8432           Clean Radio Iron Automatic Sense      1
#
# Products with Maximum Price:
#                                               name  price
# 1115                         Portable Mixer Vacuum    999
# 1334             Portable Speaker Powerbank Camera    999
# 1747                                  Charger Lamp    999
# 2717                                    Mini Brush    999
# ...

# %%
#3.	What is the average stock per category?
data.groupby("category")["stock"].mean()
# Out:
# category
# Accessories (Bags, Hats, Belts)    534.665414
# Automotive                         474.203279
# Beauty & Personal Care             520.133987
# Bedding & Bath                     511.261364
# Books & Stationery                 509.365449
# Cameras & Accessories              505.122581
# Camping & Hiking                   524.104575
# Cleaning Supplies                  486.647887
# Clothing & Apparel                 544.487500
# Cycling                            514.609319
# Fishing & Hunting                  468.286667
# Fitness Equipment                  465.794964
# Fragrances                         513.209059
# Furniture                          481.780069
# Grooming Tools                     509.434084
# Haircare                           527.373288
# Headphones & Earbuds               502.334405
# Health & Wellness                  518.380645
# Home & Kitchen                     492.680380
# Home Decor                         490.006601
# ...

# %%
#4.	What is the total stock across all products?
print("Stock of all products are:",data["stock"].sum())
# Out:
# Stock of all products are: 4992580

# %%
#5.	What is the median price of products in "Kitchen Appliances"?
data.loc[data["category"]=="Kitchen Appliances","price"].median()
# Out:
# 474.0

# %%
#6.	What is the distribution of Availability values (in_stock vs pre_order)?
data["availability"].value_counts()
# Out:
# availability
# discontinued     1706
# out_of_stock     1700
# pre_order        1673
# limited_stock    1644
# in_stock         1644
# backorder        1633
# Name: count, dtype: int64

# %%
                                                #7. GroupBy & Aggregations
#1.	Average price per category.
data.groupby("category")["price"].mean()
# Out:
# category
# Accessories (Bags, Hats, Belts)    491.146617
# Automotive                         506.744262
# Beauty & Personal Care             518.562092
# Bedding & Bath                     503.348485
# Books & Stationery                 496.870432
# Cameras & Accessories              491.416129
# Camping & Hiking                   487.117647
# Cleaning Supplies                  528.669014
# Clothing & Apparel                 484.987500
# Cycling                            536.207885
# Fishing & Hunting                  526.430000
# Fitness Equipment                  489.003597
# Fragrances                         500.090592
# Furniture                          490.697595
# Grooming Tools                     522.353698
# Haircare                           494.102740
# Headphones & Earbuds               525.215434
# Health & Wellness                  480.193548
# Home & Kitchen                     499.629747
# Home Decor                         484.524752
# ...

# %%
#2.	Total stock per brand.
data.groupby("brand")["stock"].sum()
# Out:
# brand
# Abbott Ltd                      712
# Abbott, Holden and Conrad       563
# Abbott, Lynch and Warner        527
# Abbott, Pitts and Charles       832
# Abbott, Zavala and Patrick      143
#                                ...
# Zuniga, Schwartz and Barber     570
# Zuniga, Zavala and Contreras     23
# Zuniga-Allen                    914
# Zuniga-Mcpherson                115
# Zuniga-Yates                    809
# Name: stock, Length: 9241, dtype: int64

# %%
#3.	Count of products per availability status.
#data["availability"].value_counts()
data.groupby("availability")["name"].count()
# Out:
# availability
# backorder        1633
# discontinued     1706
# in_stock         1644
# limited_stock    1644
# out_of_stock     1700
# pre_order        1673
# Name: name, dtype: int64

# %%
#4.	Minimum, maximum, and average stock per category.
data.groupby("category")["stock"].agg(["max", "min", "mean"])
# Out:
#                                  max  min        mean
# category
# Accessories (Bags, Hats, Belts)  994    1  534.665414
# Automotive                       999    1  474.203279
# Beauty & Personal Care           997    4  520.133987
# Bedding & Bath                   988    1  511.261364
# Books & Stationery               990    4  509.365449
# Cameras & Accessories            996    2  505.122581
# Camping & Hiking                 999   19  524.104575
# Cleaning Supplies                996    1  486.647887
# Clothing & Apparel               997    6  544.487500
# Cycling                          995    4  514.609319
# Fishing & Hunting                999    3  468.286667
# Fitness Equipment                999    1  465.794964
# Fragrances                       996   17  513.209059
# Furniture                        990    2  481.780069
# Grooming Tools                   999   15  509.434084
# Haircare                         990    1  527.373288
# ...

# %%
#5.	Average price per brand and per category (multi-level groupby).
data.groupby(["brand", "category"])["price"].mean()
# Out:
# brand                         category
# Abbott Ltd                    Fishing & Hunting          95.0
# Abbott, Holden and Conrad     Shoes & Footwear          800.0
# Abbott, Lynch and Warner      Health & Wellness         521.0
# Abbott, Pitts and Charles     Books & Stationery        527.0
# Abbott, Zavala and Patrick    Beauty & Personal Care    611.0
#                                                         ...
# Zuniga, Schwartz and Barber   Home & Kitchen            664.0
# Zuniga, Zavala and Contreras  Fishing & Hunting          71.0
# Zuniga-Allen                  Automotive                496.0
# Zuniga-Mcpherson              Kids' Clothing            969.0
# Zuniga-Yates                  Clothing & Apparel         32.0
# Name: price, Length: 9976, dtype: float64

# %%
#6.	For each brand, which product has the highest price?
idx=data.groupby(["brand","name"])["price"].idxmax()
highest_price_per_brand = data.loc[idx, ["brand", "name", "price"]]
(highest_price_per_brand)
# Out:
#                              brand  \
# 1777                    Abbott Ltd
# 8670     Abbott, Holden and Conrad
# 3849      Abbott, Lynch and Warner
# 534      Abbott, Pitts and Charles
# 1218    Abbott, Zavala and Patrick
# ...                            ...
# 9751   Zuniga, Schwartz and Barber
# 1535  Zuniga, Zavala and Contreras
# 3784                  Zuniga-Allen
# 2014              Zuniga-Mcpherson
# 3125                  Zuniga-Yates
#
#                                              name  price
# 1777     Fast Charger Treadmill Wireless 360 Edge     95
# 8670                             Clean Stove Iron    800
# 3849                     Mini Radio Light Fan Air    521
# 534                         Ultra Freezer Premium    527
# 1218                       Ultra Grill Grill Lite    611
# ...                                           ...    ...
# 9751         Automatic Bicycle Sense Wireless 360    664
# 1535  Rechargeable Keyboard Freezer Premium Sense     71
# ...

# %%
data.groupby(["brand","name",])["price"].max()
# Out:
# brand                         name
# Abbott Ltd                    Fast Charger Treadmill Wireless 360 Edge        95
# Abbott, Holden and Conrad     Clean Stove Iron                               800
# Abbott, Lynch and Warner      Mini Radio Light Fan Air                       521
# Abbott, Pitts and Charles     Ultra Freezer Premium                          527
# Abbott, Zavala and Patrick    Ultra Grill Grill Lite                         611
#                                                                             ...
# Zuniga, Schwartz and Barber   Automatic Bicycle Sense Wireless 360           664
# Zuniga, Zavala and Contreras  Rechargeable Keyboard Freezer Premium Sense     71
# Zuniga-Allen                  Stove Iron                                     496
# Zuniga-Mcpherson              Ultra Scanner Shaver Powerbank                 969
# Zuniga-Yates                  Automatic Treadmill                             32
# Name: price, Length: 10000, dtype: int64

# %%
                                                         #8. Transform & New Columns
#1.	Add a new column: Price_with_Tax = Price * 1.15 (assuming 15% tax).
data["Price_with_Tax"] = (data["price"] * 1.15).round(2)
data
# Out:
#       index                                        name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 3         4              Premium Grill Trimmer Portable
# 4         5                            Keyboard Freezer
# ...     ...                                         ...
# 9995   9996                                   Powerbank
# 9996   9997            Rechargeable Lamp Scanner Vacuum
# 9997   9998                                      Heater
# 9998   9999               Rechargeable Headphones Stove
# 9999  10000                     Clean Charger Treadmill
#
#                                             description  \
# 0                             Catch enough role nearly.
# 1                             All movement yeah tax me.
# 2                   Quickly inside pull line lay start.
# 3                                 Lawyer one than fire.
# ...

# %%
#2.	Add a new column: average price per category (using transform).
data["Avg_price"] = data.groupby("category")["price"].transform("mean")
data
# Out:
#       index                                        name  \
# 0         1  Smart Fan Iron Cooker Go Wireless Portable
# 1         2                                         Fan
# 2         3   Smart Speakerphone Charger Eco Plus Clean
# 3         4              Premium Grill Trimmer Portable
# 4         5                            Keyboard Freezer
# ...     ...                                         ...
# 9995   9996                                   Powerbank
# 9996   9997            Rechargeable Lamp Scanner Vacuum
# 9997   9998                                      Heater
# 9998   9999               Rechargeable Headphones Stove
# 9999  10000                     Clean Charger Treadmill
#
#                                             description  \
# 0                             Catch enough role nearly.
# 1                             All movement yeah tax me.
# 2                   Quickly inside pull line lay start.
# 3                                 Lawyer one than fire.
# ...

# %%
#3.	Add a column: difference between each product’s price and its category average.
data["price_diff_from_cat_avg"] = data["price"] - data.groupby("category")["price"].transform("mean")

data.head()
# Out:
#    index                                        name  \
# 0      1  Smart Fan Iron Cooker Go Wireless Portable
# 1      2                                         Fan
# 2      3   Smart Speakerphone Charger Eco Plus Clean
# 3      4              Premium Grill Trimmer Portable
# 4      5                            Keyboard Freezer
#
#                            description                    brand  \
# 0            Catch enough role nearly.               Herman Ltd
# 1            All movement yeah tax me.  Braun, King and Rollins
# 2  Quickly inside pull line lay start.             Peck-Coleman
# 3                Lawyer one than fire.                Hines Ltd
# 4    Remain Congress blood plan voice.  Spence, Webster and Orr
#
#               category  price currency  stock            ean        color  \
# 0       Kids' Clothing    585      USD    194  3968600833473     Cornsilk
# 1       Grooming Tools    992      USD    724   191126950284       Bisque
# ...

# %%
#4.	Add a column: % contribution of each product’s stock to its category stock.
data["stock_pct_of_category"] = (data["stock"] / data.groupby("category")["stock"].transform("sum") * 100).round(2)
data.head()
# Out:
#    index                                        name  \
# 0      1  Smart Fan Iron Cooker Go Wireless Portable
# 1      2                                         Fan
# 2      3   Smart Speakerphone Charger Eco Plus Clean
# 3      4              Premium Grill Trimmer Portable
# 4      5                            Keyboard Freezer
#
#                            description                    brand  \
# 0            Catch enough role nearly.               Herman Ltd
# 1            All movement yeah tax me.  Braun, King and Rollins
# 2  Quickly inside pull line lay start.             Peck-Coleman
# 3                Lawyer one than fire.                Hines Ltd
# 4    Remain Congress blood plan voice.  Spence, Webster and Orr
#
#               category  price currency  stock            ean        color  \
# 0       Kids' Clothing    585      USD    194  3968600833473     Cornsilk
# 1       Grooming Tools    992      USD    724   191126950284       Bisque
# ...

# %%
#5.	Rank products within each category by price.
data["Rank_by_price"]=data.groupby("category")["price"].rank(method="dense", ascending=False)
data.head(10)
# Out:
#    index                                        name  \
# 0      1  Smart Fan Iron Cooker Go Wireless Portable
# 1      2                                         Fan
# 2      3   Smart Speakerphone Charger Eco Plus Clean
# 3      4              Premium Grill Trimmer Portable
# 4      5                            Keyboard Freezer
# 5      6                           Smart Fridge Plus
# 6      7          Compact Dock One Portable Wireless
# 7      8           Premium Cooler Digital Portable X
# 8      9              Compact Fan Scooter Headphones
# 9     10                                Eco Dock Air
#
#                                       description  \
# 0                       Catch enough role nearly.
# 1                       All movement yeah tax me.
# 2             Quickly inside pull line lay start.
# 3                           Lawyer one than fire.
# 4               Remain Congress blood plan voice.
# 5             Tell tend provide government voice.
# ...

# %%
                                                                 #10. Duplicates & IDs
#1.	Check if there are duplicate Internal ID values.
print("Duplicate values in internal id are :",data.duplicated("internal_id").sum())
#data.duplicated("internal_id").sum()
#data
# Out:
# Duplicate values in internal id are : 9901

# %%
                                                           #9. String Operations
#1.	Extract the first 10 characters of Description.
data["Description"].str[:10]
# Out:
# 0       Catch enou
# 1       All moveme
# 2       Quickly in
# 3       Lawyer one
# 4       Remain Con
#            ...
# 9995    Yeah none
# 9996    Appear cou
# 9997    Owner plan
# 9998    Base accou
# 9999    Return ref
# Name: Description, Length: 10000, dtype: object

# %%
#2.	Count how many product names contain the word "Digital".
print("Names contain digital are :",data["Name"].str.contains("Digital", case=False).sum())
# Out:
# Names contain digital are : 839

# %%
#3.	Convert all brand names to uppercase.
data["brand_upper"] = data["Brand"].str.upper()
data.head()
# Out:
#    Index                                        Name  \
# 0      1  Smart Fan Iron Cooker Go Wireless Portable
# 1      2                                         Fan
# 2      3   Smart Speakerphone Charger Eco Plus Clean
# 3      4              Premium Grill Trimmer Portable
# 4      5                            Keyboard Freezer
#
#                            Description                    Brand  \
# 0            Catch enough role nearly.               Herman Ltd
# 1            All movement yeah tax me.  Braun, King and Rollins
# 2  Quickly inside pull line lay start.             Peck-Coleman
# 3                Lawyer one than fire.                Hines Ltd
# 4    Remain Congress blood plan voice.  Spence, Webster and Orr
#
#               Category  Price Currency  Stock            EAN        Color  \
# 0       Kids' Clothing    585      USD    194  3968600833473     Cornsilk
# 1       Grooming Tools    992      USD    724   191126950284       Bisque
# ...

# %%
#4.	Find all products where Description contains "memory".
print("These are:",data["Category"].str.contains("memory",case=False).sum())
# Out:
# These are: 0

# %%
#5.	Get the length of each product name.
data["Name"].str.len()
# Out:
# 0       42
# 1        3
# 2       41
# 3       30
# 4       16
#         ..
# 9995     9
# 9996    32
# 9997     6
# 9998    29
# 9999    23
# Name: Name, Length: 10000, dtype: int64

# %%
                                                              #11. Advanced Filtering
#1.	Show top 5 most expensive products.
data.nlargest(5, "Price")
#nlargest(n, column)
# Out:
#       Index                               Name  \
# 1115   1116              Portable Mixer Vacuum
# 1334   1335  Portable Speaker Powerbank Camera
# 1747   1748                       Charger Lamp
# 2717   2718                         Mini Brush
# 3576   3577    Pro Clock Router Fridge Air Max
#
#                                             Description  \
# 1115  Describe institution interest job medical wall...
# 1334               Begin research price air minute add.
# 1747  Generation suggest cup industry nearly yet org...
# 2717      Sport front run group let gun partner others.
# 3576                Term return thought apply thousand.
#
#                             Brand            Category  Price Currency  Stock  \
# 1115                  Villa-Yates      Men's Clothing    999      USD    842
# 1334     Caldwell, Bowen and Byrd     Office Supplies    999      USD    563
# 1747             Jefferson-Reeves      Men's Clothing    999      USD    925
# ...

# %%
#2.	Show top 5 products with the lowest stock.
data.nsmallest(5, "Stock")
# Out:
#       Index                                     Name  \
# 174     175  Advanced Dock Automatic Silent Portable
# 414     415                     Portable Drone Clean
# 497     498      Smart Charger Mini Max Rechargeable
# 558     559                 Advanced Router Portable
# 3164   3165                Ultra Radio Smart Max 360
#
#                                             Description  \
# 174                         Hope star recently certain.
# 414             Trouble current admit style collection.
# 497                    Product world head dinner there.
# 558   Wear about reason full able environment party to.
# 3164                                  Part economic TV.
#
#                              Brand           Category  Price Currency  Stock  \
# 174                      Brady PLC         Automotive    563      USD      1
# 414                    Wilkins Ltd             Makeup    130      USD      1
# ...

# %%
#3.	Find the category with the most products.
data["Category"].value_counts().head(1)
# head(1) srf top 1 wali dikhaye gaa
# Out:
# Category
# Clothing & Apparel    320
# Name: count, dtype: int64

# %%
#4.	Find the brand with the highest total stock.
data.groupby("Brand")["Stock"].sum().sort_values(ascending=False).head(1)
# Out:
# Brand
# Kennedy LLC    3176
# Name: Stock, dtype: int64

# %%
#5.	Find all products where stock is above the category average stock.
cat_avg_stock = data.groupby("Category")["Stock"].transform("mean")
data[data["Stock"] > cat_avg_stock]
# Out:
#       Index                                       Name  \
# 1         2                                        Fan
# 2         3  Smart Speakerphone Charger Eco Plus Clean
# 4         5                           Keyboard Freezer
# 5         6                          Smart Fridge Plus
# 7         8          Premium Cooler Digital Portable X
# ...     ...                                        ...
# 9989   9990                         Smart Speakerphone
# 9990   9991  Wireless Iron Toaster Projector Automatic
# 9992   9993          Smart Trimmer Stove Advanced Plus
# 9994   9995                                    Blender
# 9997   9998                                     Heater
#
#                                             Description  \
# 1                             All movement yeah tax me.
# 2                   Quickly inside pull line lay start.
# 4                     Remain Congress blood plan voice.
# 5                   Tell tend provide government voice.
# ...

# %%
                                                      #12. Combination & Wrangling
#1.	Create a summary DataFrame with columns:
#Category, Total_Products, Avg_Price, Total_Stock, Min_Price, Max_Price
summary = data.groupby("Category").agg(
    Total_Products=("Name", "count"),
    Avg_Price=("Price", "mean"),
    Total_Stock=("Stock", "sum"),
    Min_Price=("Price", "min"),
    Max_Price=("Price", "max")
).reset_index()
summary
# Out:
#                            Category  Total_Products   Avg_Price  Total_Stock  \
# 0   Accessories (Bags, Hats, Belts)             266  491.146617       142221
# 1                        Automotive             305  506.744262       144632
# 2            Beauty & Personal Care             306  518.562092       159161
# 3                    Bedding & Bath             264  503.348485       134973
# 4                Books & Stationery             301  496.870432       153319
# 5             Cameras & Accessories             310  491.416129       156588
# 6                  Camping & Hiking             306  487.117647       160376
# 7                 Cleaning Supplies             284  528.669014       138208
# 8                Clothing & Apparel             320  484.987500       174236
# 9                           Cycling             279  536.207885       143576
# 10                Fishing & Hunting             300  526.430000       140486
# ...

# %%
#2.	Find the ratio of in_stock to pre_order products per category.
availability_ratio = (
    data.groupby(["Category", "Availability"])["Name"]
    .count()
    .unstack(fill_value=0)
)
availability_ratio["ratio_instock_preorder"] = (
    availability_ratio.get("in_stock", 0) / availability_ratio.get("pre_order", 1)
)
availability_ratio
# Out:
# Availability                     backorder  discontinued  in_stock  \
# Category
# Accessories (Bags, Hats, Belts)         39            43        45
# Automotive                              47            36        55
# Beauty & Personal Care                  50            47        48
# Bedding & Bath                          43            53        43
# Books & Stationery                      51            55        51
# Cameras & Accessories                   54            55        56
# Camping & Hiking                        56            49        50
# Cleaning Supplies                       48            49        50
# Clothing & Apparel                      61            56        41
# Cycling                                 48            49        46
# Fishing & Hunting                       39            62        44
# Fitness Equipment                       53            48        48
# Fragrances                              42            55        55
# ...

# %%
#3. For each brand: number of products, total stock, average price
brand_summary = data.groupby("Brand").agg(
    num_products=("Name", "count"),
    total_stock=("Stock", "sum"),
    avg_price=("Price", "mean")
).reset_index()
brand_summary
# Out:
#                              Brand  num_products  total_stock  avg_price
# 0                       Abbott Ltd             1          712       95.0
# 1        Abbott, Holden and Conrad             1          563      800.0
# 2         Abbott, Lynch and Warner             1          527      521.0
# 3        Abbott, Pitts and Charles             1          832      527.0
# 4       Abbott, Zavala and Patrick             1          143      611.0
# ...                            ...           ...          ...        ...
# 9236   Zuniga, Schwartz and Barber             1          570      664.0
# 9237  Zuniga, Zavala and Contreras             1           23       71.0
# 9238                  Zuniga-Allen             1          914      496.0
# 9239              Zuniga-Mcpherson             1          115      969.0
# 9240                  Zuniga-Yates             1          809       32.0
#
# [9241 rows x 4 columns]

# %%
#4.	Create a column that says "High Stock" if Stock > 500, otherwise "Low Stock".
data["stock_level"] = data["Stock"].apply(lambda x: "High Stock" if x > 500 else "Low Stock")
data["stock_level"]
# Out:
# 0        Low Stock
# 1       High Stock
# 2       High Stock
# 3        Low Stock
# 4       High Stock
#            ...
# 9995     Low Stock
# 9996     Low Stock
# 9997    High Stock
# 9998     Low Stock
# 9999     Low Stock
# Name: stock_level, Length: 10000, dtype: object
